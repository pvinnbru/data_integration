# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
import copy

# Connection string
connection_string = "postgresql://postgres.svsobttfvdpdxpiwjeqg:z36ow70ANRJB5GHa@aws-0-eu-central-1.pooler.supabase.com:6543/postgres"
engine = create_engine(connection_string)

# Load tables from the database
dive_sites = pd.read_sql("SELECT * FROM dive_site", con=engine)
user_ratings_data = pd.read_sql("SELECT * FROM dive_site_rating", con=engine)
occurrences = pd.read_sql("SELECT * FROM occurrence", con=engine)
animals = pd.read_sql("SELECT * FROM animal", con=engine)
animals_ratings = pd.read_sql("SELECT * FROM animal_rating", con=engine)
categories = pd.read_sql("SELECT * FROM dive_site_category", con=engine)
categories_per_dive_site = pd.read_sql("SELECT * FROM categories_per_dive_site", con=engine)
alembic_version = pd.read_sql("SELECT * FROM alembic_version", con=engine)

# sort the dive sites by the id
dive_sites = dive_sites.sort_values(by='id')
dive_sites
# Out:
#         id                       title       lat       long  \
# 46       1                   HMS Maori  35.90250   14.51532
# 47       2      USAT Liberty Shipwreck  -8.27396  115.59307
# 48       3                         Ped  -8.67438  115.51499
# 49       4                 Manta Point  -8.79547  115.52553
# 42       5  THE HOLE / GREEN BAY CAVES  34.99989   34.06868
# ...    ...                         ...       ...        ...
# 4390  4391              Lekuan 1, 2, 3   1.59822  124.76752
# 4391  4392                     Moc-Che  20.64070  -87.04884
# 4392  4393                 Fish Market  20.81187  -86.88260
# 4393  4394           The Zenobia Wreck  34.88500   33.74000
# 4394  4395                   18th Palm  12.13785  -68.27659
#
#                                             description  \
# 46    Max Depth: -15mt √ Shore dive √ Beginners Free...
# 47    This is probably the most famous dive site in ...
# 48    Ped dive site consists of a fairly wide and sh...
# 49    One of the most famous dive sites in the Bali ...
# 42    Shore entry leading over reefs to a series of ...
# ...                                                 ...
# 4390  One of the most popular dive sites on Bunaken ...
# 4391                                               None
# 4392  Shallow reef, FULL of fish. 30 ft maximum dept...
# 4393  The Zenobia Wreck is one of the top ten wreck ...
# 4394  House reef of Plaza Beach & Dive Resort and To...
#
#                                               image_url  \
# 46    https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 47    https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 48    https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 49    https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 42    https://d2p1cf6997m1ir.cloudfront.net/media/th...
# ...                                                 ...
# 4390  https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 4391  https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 4392  https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 4393  https://d2p1cf6997m1ir.cloudfront.net/media/th...
# 4394  https://d2p1cf6997m1ir.cloudfront.net/media/th...
#
#                                                     url             max_depth  \
# 46      https://www.padi.com/dive-site/malta/hms-maori/                  None
# 47    https://www.padi.com/dive-site/indonesia/usat-...                  None
# 48        https://www.padi.com/dive-site/indonesia/ped/                  None
# 49    https://www.padi.com/dive-site/indonesia/manta...   65 feet / 20 meters
# 42    https://www.padi.com/dive-site/cyprus/the-hole...                  None
# ...                                                 ...                   ...
# 4390  https://www.padi.com/dive-site/indonesia/lekua...                  None
# 4391     https://www.padi.com/dive-site/mexico/moc-che/                  None
# 4392  https://www.padi.com/dive-site/mexico/fish-mar...                  None
# 4393  https://www.padi.com/dive-site/cyprus/the-zeno...  137 feet / 42 meters
# 4394  https://www.padi.com/dive-site/bonaire/18th-palm/                  None
#
#          region  cluster
# 46        Malta        2
# 47    Indonesia        7
# 48    Indonesia        1
# 49    Indonesia        2
# 42       Cyprus        1
# ...         ...      ...
# 4390  Indonesia        7
# 4391     Mexico        2
# 4392     Mexico        2
# 4393     Cyprus        6
# 4394    Bonaire        7
#
# [4395 rows x 10 columns]

# %%
# Query to list all tables in the 'public' schema
query = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public';
"""

# Load the table names into a DataFrame
tables = pd.read_sql(query, con=engine)

tables
# Out:
#                   table_name
# 0               user_vectors
# 1               item_vectors
# 2   categories_per_dive_site
# 3                  dive_site
# 4            alembic_version
# 5         dive_site_category
# 6                 occurrence
# 7              animal_rating
# 8                     animal
# 9                       user
# 10          dive_site_rating

# %%
occurrences
# Out:
#           id  dive_site_id  animal_id
# 0          1             1          1
# 1          2             1          2
# 2          3             1          3
# 3          4             1          4
# 4          5             1          5
# ...      ...           ...        ...
# 21803  21856          4395         51
# 21804  21857          4395         92
# 21805  21858          4395          2
# 21806  21859          4395         37
# 21807  21860          4395         74
#
# [21808 rows x 3 columns]

# %%
categories_per_dive_site
# Out:
#       dive_site_id  dive_site_category_id
# 0                1                      1
# 1                1                      2
# 2                2                      1
# 3                2                      3
# 4                2                      4
# ...            ...                    ...
# 8553          4392                      2
# 8554          4393                      2
# 8555          4394                      1
# 8556          4394                     10
# 8557          4395                      3
#
# [8558 rows x 2 columns]

# %%
categories
# Out:
#     id            name                                          image_url
# 0   20           Fjord  https://www.divingsquad.com/wp-content/uploads...
# 1   18            Muck  https://murexresorts.com/wp-content/uploads/20...
# 2   19        Sea Loch  https://meanderapparel.com/cdn/shop/articles/r...
# 3   17          Spring  https://imgds360live.s3.amazonaws.com/storefro...
# 4   16            Pool  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5   15  Archaeological  https://marineprotectedareas.noaa.gov/toolkit/...
# 6   14          Quarry  https://images.downeast.com/wp-content/uploads...
# 7   13        Pinnacle  https://go2similan.com/wp-content/uploads/2021...
# 8   12          Cavern  https://aquaworld.com.mx/uploads/0000/1/2023/0...
# 9   11           River  https://www.macssports.com/wp-content/uploads/...
# 10  10    Sandy bottom  https://images.pond5.com/group-scuba-divers-di...
# 11   9            Lake  https://tahoequarterly.com/wp-content/uploads/...
# 12   8           Ocean  https://media.istockphoto.com/id/484092196/de/...
# 13   7         Channel  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 14   6            Cave  https://www.scubadiving.com/sites/default/file...
# 15   5           Drift  https://www.deeperblue.com/wp-content/uploads/...
# 16   4            Wall  https://originaldiving.d3r.site/images/spotlig...
# 17   3           Beach  https://dtmag.com/wp-content/uploads/2003/05/s...
# 18   2            Reef  https://www.zubludiving.com/images/Indonesia/W...
# 19   1           Wreck  https://res.cloudinary.com/padi/image/upload/f...

# %%
animals
# Out:
#       id                 name  \
# 0    149          Spider Crab
# 1    325           Ribbon Eel
# 2     83       Chondrichthyes
# 3    121            Jellyfish
# 4      1            Moray Eel
# ..   ...                  ...
# 495  498  Heteractis Anemones
# 496  499         Rocketfishes
# 497  500          Serpent Eel
# 498  254          Tree Dorids
# 499  446          Desmacidids
#
#                                              image_url
# 0     https://i.ytimg.com/vi/knh7lQFWnnw/hqdefault.jpg
# 1    https://i0.wp.com/www.australiangeographic.com...
# 2    https://cdn.oceanographicmagazine.com/wp-conte...
# 3    https://s3.eu-west-1.amazonaws.com/media.mcsuk...
# 4    https://blog.mares.com/wp-content/uploads/2017...
# ..                                                 ...
# 495  https://as1.ftcdn.net/v2/jpg/01/65/57/74/1000_...
# 496  https://www.montereybayaquarium.org/globalasse...
# 497  https://upload.wikimedia.org/wikipedia/commons...
# 498  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 499  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [500 rows x 3 columns]

# %%
# Analyse if animal names are unique
animal_names = animals['name'].values
unique_animal_names = np.unique(animal_names)
print("Number of animals: ", len(animal_names))
print("Number of unique animal names: ", len(unique_animal_names))
# Out:
# Number of animals:  500
# Number of unique animal names:  500

# %%
# Analyze categotires_per_dive_site: How many dive sites have no categories? 3/4392
# check if every dive site id appears in the categories_per_dive_site table
dive_sites['id'].isin(categories_per_dive_site['dive_site_id']).value_counts()
# Out:
# id
# True     4392
# False       3
# Name: count, dtype: int64

# %%
# how many dive sites have no description? -> 12,7 % of the dive sites have no description
dive_sites['description'].isnull().sum() / len(dive_sites)

#how many dive sites have no max_depth? -> 50 % of the dive sites have no max_depth
dive_sites['max_depth'].isnull().sum() / len(dive_sites)
# Out:
# np.float64(0.48282138794084184)

# %%
# get the max and min of latitude and longitude
dive_sites[['lat', 'long']].describe()
# Out:
#                lat         long
# count  4395.000000  4395.000000
# mean     19.856706    20.518053
# std      22.578385    79.242567
# min     -45.773550  -169.935680
# 25%       8.567945   -59.634820
# 50%      20.450980    14.285760
# 75%      38.009065    99.811555
# max      69.639000   179.934040

# %% [markdown]
# We need a vector-like representation for each dive-site:
# - geodata latitude, longitude
# - category
# - animals

# %% [markdown]
# Create a vector like representation for each dive site.

# %%
# This needs to be stored in the database

# let's generate a copy for the current dive sites dataframe
converted_dive_sites = copy.deepcopy(dive_sites)    

# for each category, we generate a new column (indicator if category is present in the list of genres)
for cat_id in categories['id']:
    # create a new column for the current category
    category_name = categories.loc[categories['id'] == cat_id, 'name'].values[0]
    converted_dive_sites[category_name] = 0

    # iterate over all rows
    for index, row in converted_dive_sites.iterrows():
        # get a list of all dive_site_category_ids for the current dive_site_id
        list_of_cat_ids = list(categories_per_dive_site[categories_per_dive_site['dive_site_id'] == row['id']]['dive_site_category_id'])
        # check if the current cat_id in the list of categories for the current dive_site_id
        if cat_id in list_of_cat_ids:
            converted_dive_sites.at[index, category_name] = 1

# Scale lat and long to be between 0 and 1 with a MinMaxScaler
scaler = MinMaxScaler()
converted_dive_sites[['lat_scaled', 'long_scaled']] = scaler.fit_transform(converted_dive_sites[['lat', 'long']])


# Initialize animal feature columns in a single operation
animal_columns = {animal_name: 0 for animal_name in animals['name']}
converted_dive_sites = pd.concat(
    [converted_dive_sites, pd.DataFrame(animal_columns, index=converted_dive_sites.index)],
    axis=1
)


# Populate the animal feature columns
for index, row in converted_dive_sites.iterrows():
    dive_site_id = row['id']
    animal_ids = occurrences[occurrences['dive_site_id'] == dive_site_id]['animal_id'].values   # get all animal_ids for the current dive_site_id
    for animal_id in animal_ids:
        animal_name = animals[animals['id'] == animal_id]['name'].values[0]
        converted_dive_sites.at[index, animal_name] = 1

# START
#  The following is just for the examples in the end, delete if not needed:

# add a new column 'occurences' to the converted_dive_sites dataframe
converted_dive_sites['occurences'] = ''
for index, row in converted_dive_sites.iterrows():
    dive_site_id = row['id']
    # get all animal names for the current dive_site_id
    animal_ids = occurrences[occurrences['dive_site_id'] == dive_site_id]['animal_id'].values
    animal_names = []
    for animal_id in animal_ids:
        animal_name = animals[animals['id'] == animal_id]['name'].values[0]
        animal_names.append(animal_name)

    animal_names = ', '.join(animal_names)
    converted_dive_sites.at[index, 'occurences'] = animal_names

# add a new column 'categories' to the converted_dive_sites dataframe
converted_dive_sites['categories'] = ''
for index, row in converted_dive_sites.iterrows():
    dive_site_id = row['id']
    # get all category names for the current dive_site_id
    category_ids = categories_per_dive_site[categories_per_dive_site['dive_site_id'] == dive_site_id]['dive_site_category_id'].values
    category_names = []
    for category_id in category_ids:
        category_name = categories[categories['id'] == category_id]['name'].values[0]
        category_names.append(category_name)

    category_names = ', '.join(category_names)
    converted_dive_sites.at[index, 'categories'] = category_names


# END


# sort converted_dive_sites by id 
# drop the label index
converted_dive_sites = converted_dive_sites.sort_values(by='id').reset_index(drop=True)

converted_dive_sites
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10080\262627485.py in ?()
#      19
#      20
#      21 # Scale lat and long to be between 0 and 1 with a MinMaxScaler
#      22 scaler = MinMaxScaler()
# ---> 23 converted_dive_sites[['lat_scaled', 'long_scaled']] = scaler.fit_transform(converted_dive_sites[['lat', 'long']])
#      24
#      25
#      26 # Initialize animal feature columns in a single operation
#
# c:\Users\pietv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#    4302         elif (
#
# c:\Users\pietv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4346                 for col in key:
#    4347                     self[col] = value
#    4348
#    4349             elif isinstance(value, np.ndarray) and value.ndim == 2:
# -> 4350                 self._iset_not_inplace(key, value)
#    4351
#    4352             elif np.ndim(value) > 1:
#    4353                 # list of lists
#
# c:\Users\pietv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4382         else:
#    4383             ilocs = self.columns.get_indexer_non_unique(key)[0]
#    4384             if (ilocs < 0).any():
#    4385                 # key entries not in self.columns
# -> 4386                 raise NotImplementedError
#    4387
#    4388             if np.shape(value)[-1] != len(ilocs):
#    4389                 raise ValueError("Columns must be same length as key")
#
# NotImplementedError:

# %%
# Quick Test

# Dive site 1 has the following animals
animal_ids_in_dive_site_1 = occurrences[occurrences['dive_site_id'] == 1]["animal_id"].tolist()

# Get the names of the animals in animal_ids_in_dive_site_1
animal_names_in_dive_site_1 = []
for animal_id in animal_ids_in_dive_site_1:
    animal_name = animals[animals['id'] == animal_id]['name'].values[0]
    animal_names_in_dive_site_1.append(animal_name)

print(animal_names_in_dive_site_1)

# Check if the columns with an animal_name included in animal_names_in_dive_site_1 are set to 1 - the rest should be 0
assert converted_dive_sites.loc[converted_dive_sites['id'] == 1, animal_names_in_dive_site_1].values.all() == 1
assert converted_dive_sites.loc[converted_dive_sites['id'] == 1, ~converted_dive_sites.columns.isin(animal_names_in_dive_site_1)].values.all() == 0

converted_dive_sites.loc[converted_dive_sites['id'] == 1, animal_names_in_dive_site_1]
# Out:
# ['Moray Eel', 'Seahorse Family', 'Flounder', 'Eagle Ray', 'Sea Anemone']
#    Moray Eel  Seahorse Family  Flounder  Eagle Ray  Sea Anemone
# 0          1                1         1          1            1

# %% [markdown]
# Get Item Profiles

# %%
# EUCLIDEAN SIMILARITY (for geodata)
# Cosine similarity is not suitable for geocoordinates. We can use Euclidean similarity instead.

def get_euclidean_similarity(v1, v2, max_distance=1):
    """
    Compute similarity between scaled geocoordinates using Euclidean distance.
    """
    lat1, lon1 = v1
    lat2, lon2 = v2
    distance = np.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)
    similarity = max(0, 1 - distance / max_distance)
    return similarity

# %%
# Cosine Similarity

def get_cosine_similarity(x, y):
    
    numerator = np.dot(x,y)
    denominator = np.linalg.norm(x) * np.linalg.norm(y)

    # sanity check: x and y must be non-zero vectors
    if denominator > 0:
        sim = numerator / denominator
    else:
        raise Exception("The cosine similarity is not defined for vectors containing only zeros!")

    return sim

# %%
get_cosine_similarity((0.33776, 0.180727), (0.790692, 0.31076))
# Out:
# np.float64(0.9931825125192547)

# %%
get_euclidean_similarity((0.33776, 0.180727), (0.790692, 0.31076))
# Out:
# np.float64(0.5287718411289495)

# %%
def get_recommendations_for_a_dive_site(dive_site_id, w_cat=1/3, w_geo=1/3, w_animal=1/3, n=10):
    """
    This function generates a recommendation based on the category & geodata of the input dive site.

    w_cat: weight for the category vector
    w_geo: weight for the geodata (lat_scaled, long_scaled) vector 
    """
    print(f"Generating recommendations for dive site with ID {dive_site_id}...")

    idx = dive_site_id-1 # index of the query dive site in the DataFrame


    # Query Dive Site: Get Feature Vectors
    # Category vector
    query_categories_vector = converted_dive_sites.loc[idx, categories['name']].to_numpy() 
    # Geodata vector
    query_geodata_vector = converted_dive_sites.loc[idx, ['lat_scaled', 'long_scaled']].to_numpy()
    # Animal vector
    query_animal_vector = converted_dive_sites.loc[idx, animals['name']].to_numpy()

    # Other Dive Sites
    
    print(f"Queried dive site index: {idx}")

    # generate recommendations
    recommendations = recommend(query_categories_vector, query_geodata_vector, query_animal_vector, w_cat, w_geo, w_animal, n)
    
    dive_sites_indexes = [d['index'] for d in recommendations]

    # return the list of titles and similarities
    recommendations_df = converted_dive_sites.loc[dive_sites_indexes, ['id', 'title', 'lat', 'long', 'occurences', 'categories']]
    recommendations_df[f'Similarity to dive site {dive_site_id}'] = [d['combined'] for d in recommendations]
    recommendations_df[f'Category Similarity to dive site {dive_site_id}'] = [d['category'] for d in recommendations]
    recommendations_df[f'Geodata Similarity to dive site {dive_site_id}'] = [d['geodata'] for d in recommendations] 
    recommendations_df[f'Animal Similarity to dive site {dive_site_id}'] = [d['animal'] for d in recommendations]

    return recommendations_df

# %% [markdown]
# # EXAMPLE RECOMMENDATIONS

# %%
# the following examples all use dive site with id = 2

print("I asked for recommendations for dive site with ID 2:")
print(converted_dive_sites.loc[1, ['id', 'title', 'lat', 'long', 'description', 'occurences', 'categories']])
# Out:
# I asked for recommendations for dive site with ID 2:
# id                                                             2
# title                                     USAT Liberty Shipwreck
# lat                                                     -8.27396
# long                                                   115.59307
# description    This is probably the most famous dive site in ...
# occurences     Sea Turtle, Jackfish, Grouper, Dorid Nudibranc...
# categories                                    Wreck, Beach, Wall
# Name: 1, dtype: object

# %% [markdown]
# ### Example 1: General Recommendation
#
# Category, Location and Occurences are equally important.

# %%
example_recommendations = get_recommendations_for_a_dive_site(2, w_cat=1/3, w_geo=1/3, w_animal=1/3, n=10)

print("\nRESULT")
example_recommendations
# Out:
# Generating recommendations for dive site with ID 2...
# Queried dive site index: 1
# Iterate over all dive sites...
#  4394 / 4395
# RESULT
#         id                                      title       lat       long  \
# 1        2                     USAT Liberty Shipwreck  -8.27396  115.59307
# 4376  4377                     USAT Liberty Shipwreck  -8.27396  115.59307
# 2858  2859  Indonesia Bali Tulamben USS Liberty Wreck  -8.27397  115.59312
# 3247  3248                                      自由号沉船  -8.27299  115.59239
# 1069  1070                                   Drop Off  -8.27779  115.59651
# 5        6                                   Tulamben  -8.27341  115.59235
# 4380  4381                                   Tulamben  -8.27341  115.59235
# 1957  1958                               Jemeluk Wall  -8.33771  115.66067
# 4151  4152                                Wreck Point  13.52245  120.98470
# 1962  1963                             Gili Meno Wall  -8.34323  116.04936
#
#                                              occurences  \
# 1     Sea Turtle, Jackfish, Grouper, Dorid Nudibranc...
# 4376  Mackerel, Cardinalfish, Butterflyfish, Gobies,...
# 2858  Baracuda, Moray Eel, Saddleback Fish, Angelfis...
# 3247  Surgeonfish, Sea Turtle, Trumpetfish, Baracuda...
# 1069  Saber-Toothed Blennies, Tigerfish, Butterflyfi...
# 5     Jackfish, Goatfish, Cuttlefish, Seahorse Famil...
# 4380  Seahorse Family, Stingray, Cuttlefish, Scorpio...
# 1957  Stingray, Lionfish, Stonefish, Sea Turtle, Dam...
# 4151  Snaper, Hawkfish, Baracuda, Tigerfish, Moray E...
# 1962  Stingray, Eagle Ray, Boxfish, Damselfish, Scor...
#
#                     categories  Similarity to dive site 2  \
# 1           Wreck, Beach, Wall                   1.000000
# 4376        Wreck, Beach, Wall                   1.000000
# 2858  Wreck, Beach, Reef, Wall                   0.955342
# 3247       Wreck, Beach, Ocean                   0.888886
# 1069         Beach, Reef, Wall                   0.888877
# 5                        Wreck                   0.855123
# 4380                     Wreck                   0.855123
# 1957               Beach, Wall                   0.730521
# 4151  Wreck, Drift, Reef, Wall                   0.698237
# 1962                      Wall                   0.691787
#
#       Category Similarity to dive site 2  Geodata Similarity to dive site 2  \
# 1                               1.000000                           1.000000
# 4376                            1.000000                           1.000000
# 2858                            0.866025                           1.000000
# 3247                            0.666667                           0.999991
# 1069                            0.666667                           0.999965
# 5                               0.577350                           0.999995
# 4380                            0.577350                           0.999995
# 1957                            0.816497                           0.999415
# 4151                            0.577350                           0.810516
# 1962                            0.577350                           0.998564
#
#       Animal Similarity to dive site 2
# 1                             1.000000
# 4376                          1.000000
# 2858                          1.000000
# 3247                          1.000000
# 1069                          1.000000
# 5                             0.988024
# 4380                          0.988024
# 1957                          0.375653
# 4151                          0.706845
# 1962                          0.499445

# %% [markdown]
# ### Example 2: Only look at geographically close dive sites to id=2. Ignore animals and categories

# %%
example_recommendations = get_recommendations_for_a_dive_site(2, w_cat=0, w_geo=1, w_animal=0, n=10)

print("\nRESULT")
example_recommendations
# Out:
# Generating recommendations for dive site with ID 2...
# Queried dive site index: 1
# Iterate over all dive sites...
#  4394 / 4395
# RESULT
#         id                                      title      lat       long  \
# 1        2                     USAT Liberty Shipwreck -8.27396  115.59307
# 4376  4377                     USAT Liberty Shipwreck -8.27396  115.59307
# 2858  2859  Indonesia Bali Tulamben USS Liberty Wreck -8.27397  115.59312
# 5        6                                   Tulamben -8.27341  115.59235
# 4380  4381                                   Tulamben -8.27341  115.59235
# 3247  3248                                      自由号沉船 -8.27299  115.59239
# 1069  1070                                   Drop Off -8.27779  115.59651
# 3237  3238                                 house reff -8.26530  115.58853
# 1041  1042              Tulamben Area (Seraya, Sidem) -8.28477  115.60512
# 1098  1099                           Kubu, Boga Wreck -8.24955  115.58064
#
#                                              occurences  \
# 1     Sea Turtle, Jackfish, Grouper, Dorid Nudibranc...
# 4376  Mackerel, Cardinalfish, Butterflyfish, Gobies,...
# 2858  Baracuda, Moray Eel, Saddleback Fish, Angelfis...
# 5     Jackfish, Goatfish, Cuttlefish, Seahorse Famil...
# 4380  Seahorse Family, Stingray, Cuttlefish, Scorpio...
# 3247  Surgeonfish, Sea Turtle, Trumpetfish, Baracuda...
# 1069  Saber-Toothed Blennies, Tigerfish, Butterflyfi...
# 3237  Baracuda, Parrotfish, Saddleback Fish, Grouper...
# 1041
# 1098
#
#                     categories  Similarity to dive site 2  \
# 1           Wreck, Beach, Wall                   1.000000
# 4376        Wreck, Beach, Wall                   1.000000
# 2858  Wreck, Beach, Reef, Wall                   1.000000
# 5                        Wreck                   0.999995
# 4380                     Wreck                   0.999995
# 3247       Wreck, Beach, Ocean                   0.999991
# 1069         Beach, Reef, Wall                   0.999965
# 3237     Beach, Reef, Sea Loch                   0.999924
# 1041                     Beach                   0.999900
# 1098               Wreck, Reef                   0.999786
#
#      Category Similarity to dive site 2  Geodata Similarity to dive site 2  \
# 1                                  None                           1.000000
# 4376                               None                           1.000000
# 2858                               None                           1.000000
# 5                                  None                           0.999995
# 4380                               None                           0.999995
# 3247                               None                           0.999991
# 1069                               None                           0.999965
# 3237                               None                           0.999924
# 1041                               None                           0.999900
# 1098                               None                           0.999786
#
#      Animal Similarity to dive site 2
# 1                                None
# 4376                             None
# 2858                             None
# 5                                None
# 4380                             None
# 3247                             None
# 1069                             None
# 3237                             None
# 1041                             None
# 1098                             None

# %% [markdown]
# ### Example 3: Get similar dive site regardless of distance

# %%
# We can also insert negative weights, e.g. w_geo = -1 to punish recommendations that are close geographically (in theory, doesnt work)

# Example: Punish recommendations that are close to the query dive site
example_recommendations = get_recommendations_for_a_dive_site(2, w_cat=0.5, w_geo=0, w_animal=0.5, n=10)

print("\nRESULT")
example_recommendations
# Out:
# Generating recommendations for dive site with ID 2...
# Queried dive site index: 1
# Iterate over all dive sites...
#  4394 / 4395
# RESULT
#         id                                      title       lat       long  \
# 1        2                     USAT Liberty Shipwreck  -8.27396  115.59307
# 4376  4377                     USAT Liberty Shipwreck  -8.27396  115.59307
# 2858  2859  Indonesia Bali Tulamben USS Liberty Wreck  -8.27397  115.59312
# 1069  1070                                   Drop Off  -8.27779  115.59651
# 3247  3248                                      自由号沉船  -8.27299  115.59239
# 5        6                                   Tulamben  -8.27341  115.59235
# 4380  4381                                   Tulamben  -8.27341  115.59235
# 683    684                                 Lighthouse  28.49902   34.51988
# 685    686                                   Mashraba  28.49520   34.51702
# 4151  4152                                Wreck Point  13.52245  120.98470
#
#                                              occurences  \
# 1     Sea Turtle, Jackfish, Grouper, Dorid Nudibranc...
# 4376  Mackerel, Cardinalfish, Butterflyfish, Gobies,...
# 2858  Baracuda, Moray Eel, Saddleback Fish, Angelfis...
# 1069  Saber-Toothed Blennies, Tigerfish, Butterflyfi...
# 3247  Surgeonfish, Sea Turtle, Trumpetfish, Baracuda...
# 5     Jackfish, Goatfish, Cuttlefish, Seahorse Famil...
# 4380  Seahorse Family, Stingray, Cuttlefish, Scorpio...
# 683   Electric Ray, Snaper, Ghostpipefish, Stonefish...
# 685   Goatfish, Leptastrea Fish, Damselfish, Moray E...
# 4151  Snaper, Hawkfish, Baracuda, Tigerfish, Moray E...
#
#                     categories  Similarity to dive site 2  \
# 1           Wreck, Beach, Wall                   1.000000
# 4376        Wreck, Beach, Wall                   1.000000
# 2858  Wreck, Beach, Reef, Wall                   0.933013
# 1069         Beach, Reef, Wall                   0.833333
# 3247       Wreck, Beach, Ocean                   0.833333
# 5                        Wreck                   0.782687
# 4380                     Wreck                   0.782687
# 683          Beach, Reef, Wall                   0.654268
# 685          Beach, Reef, Wall                   0.650112
# 4151  Wreck, Drift, Reef, Wall                   0.642098
#
#       Category Similarity to dive site 2 Geodata Similarity to dive site 2  \
# 1                               1.000000                              None
# 4376                            1.000000                              None
# 2858                            0.866025                              None
# 1069                            0.666667                              None
# 3247                            0.666667                              None
# 5                               0.577350                              None
# 4380                            0.577350                              None
# 683                             0.666667                              None
# 685                             0.666667                              None
# 4151                            0.577350                              None
#
#       Animal Similarity to dive site 2
# 1                             1.000000
# 4376                          1.000000
# 2858                          1.000000
# 1069                          1.000000
# 3247                          1.000000
# 5                             0.988024
# 4380                          0.988024
# 683                           0.641870
# 685                           0.633556
# 4151                          0.706845

# %% [markdown]
# ### Example 4: Find dive sites with a similar profile, prioritise result that are far away

# %%
# Example: Punish recommendations that are close to the query dive site
# CAUTION! Summed weights should be 1
example_recommendations = get_recommendations_for_a_dive_site(2, w_cat=0.75, w_geo=-0.5, w_animal=0.75, n=10)

print("\nRESULT")
example_recommendations
# Out:
# Generating recommendations for dive site with ID 2...
# Queried dive site index: 1
# Iterate over all dive sites...
#  4394 / 4395
# RESULT
#         id                                      title        lat        long  \
# 1        2                     USAT Liberty Shipwreck  -8.273960  115.593070
# 4376  4377                     USAT Liberty Shipwreck  -8.273960  115.593070
# 2858  2859  Indonesia Bali Tulamben USS Liberty Wreck  -8.273970  115.593120
# 1069  1070                                   Drop Off  -8.277790  115.596510
# 3247  3248                                      自由号沉船  -8.272990  115.592390
# 3577  3578                                Front Porch  12.164510  -68.287220
# 683    684                                 Lighthouse  28.499020   34.519880
# 5        6                                   Tulamben  -8.273410  115.592350
# 4380  4381                                   Tulamben  -8.273410  115.592350
# 668    669                                 USCGC Bibb  25.004902  -80.373159
#
#                                              occurences  \
# 1     Sea Turtle, Jackfish, Grouper, Dorid Nudibranc...
# 4376  Mackerel, Cardinalfish, Butterflyfish, Gobies,...
# 2858  Baracuda, Moray Eel, Saddleback Fish, Angelfis...
# 1069  Saber-Toothed Blennies, Tigerfish, Butterflyfi...
# 3247  Surgeonfish, Sea Turtle, Trumpetfish, Baracuda...
# 3577  Pufferfish, Brain Coral, Serpulid Worms, Ircin...
# 683   Electric Ray, Snaper, Ghostpipefish, Stonefish...
# 5     Jackfish, Goatfish, Cuttlefish, Seahorse Famil...
# 4380  Seahorse Family, Stingray, Cuttlefish, Scorpio...
# 668   Angelfish, Requiem Sharks, Eagle Ray, Snaper, ...
#
#                     categories  Similarity to dive site 2  \
# 1           Wreck, Beach, Wall                   1.000000
# 4376        Wreck, Beach, Wall                   1.000000
# 2858  Wreck, Beach, Reef, Wall                   0.899519
# 1069         Beach, Reef, Wall                   0.750017
# 3247       Wreck, Beach, Ocean                   0.750004
# 3577        Wreck, Beach, Reef                   0.684258
# 683          Beach, Reef, Wall                   0.678390
# 5                        Wreck                   0.674033
# 4380                     Wreck                   0.674033
# 668                      Wreck                   0.672529
#
#       Category Similarity to dive site 2  Geodata Similarity to dive site 2  \
# 1                               1.000000                           1.000000
# 4376                            1.000000                           1.000000
# 2858                            0.866025                           1.000000
# 1069                            0.666667                           0.999965
# 3247                            0.666667                           0.999991
# 3577                            0.666667                           0.445399
# 683                             0.666667                           0.606025
# 5                               0.577350                           0.999995
# 4380                            0.577350                           0.999995
# 668                             0.577350                           0.370024
#
#       Animal Similarity to dive site 2
# 1                             1.000000
# 4376                          1.000000
# 2858                          1.000000
# 1069                          1.000000
# 3247                          1.000000
# 3577                          0.542610
# 683                           0.641870
# 5                             0.988024
# 4380                          0.988024
# 668                           0.566038

# %% [markdown]
# # ADDING USER PROFILE

# %%
user = pd.read_sql('SELECT * FROM "user"', con=engine)

#user
# Out:
#                    name                        email  \
# 0     Steffen Kirchhoff   steffen.kirchhoff99@gmx.de
# 1        Dominik Eitner      dominikeitner@gmail.com
# 2     Veronica Thompson    crystalrogers@example.com
# 3        Melissa Hoover  harriselizabeth@example.com
# 4           Karen Allen        tammyhuff@example.org
# ..                  ...                          ...
# 397          Tracy Haas          etucker@example.org
# 398       Marie Herrera  elizabethtaylor@example.com
# 399       Philip Stuart         amanda39@example.com
# 400    Robert Middleton       jennifer16@example.org
# 401  Stephanie Sullivan       dennisbell@example.com
#
#                                        id
# 0    152e8e72-c295-4a60-9249-63d6aba3be23
# 1    1b4839eb-7c8a-4598-9ce6-a4e2cb9e8f8f
# 2    f8f0a8f5-599a-4874-bef5-a0d33b1f6467
# 3    975185b7-0919-4726-b132-c83e95010e53
# 4    9701fe9f-e2c5-4ab4-bcd9-ee1c38fc2c71
# ..                                    ...
# 397  5bad2a20-80f8-4706-b284-599433d3e456
# 398  02cb64d2-9a73-4b18-bf26-9648a4516d4f
# 399  df7c9f90-78a0-49b0-abdb-af10595b6e86
# 400  4b62f0d4-6ae2-4e91-aae9-0d01fa5862cb
# 401  e356a22b-45a6-450d-a745-b6ad659af4ae
#
# [402 rows x 3 columns]

# %%
# TODO: Can be deleted as soon as lat and long is added to the user database

# Add lat and long columns to user dataframe

user['user_lat'] = np.random.uniform(-90, 90, len(user))
user['user_long'] = np.random.uniform(-180, 180, len(user))

user
# Out:
#                    name                        email  \
# 0     Steffen Kirchhoff   steffen.kirchhoff99@gmx.de
# 1        Dominik Eitner      dominikeitner@gmail.com
# 2     Veronica Thompson    crystalrogers@example.com
# 3        Melissa Hoover  harriselizabeth@example.com
# 4           Karen Allen        tammyhuff@example.org
# ..                  ...                          ...
# 397          Tracy Haas          etucker@example.org
# 398       Marie Herrera  elizabethtaylor@example.com
# 399       Philip Stuart         amanda39@example.com
# 400    Robert Middleton       jennifer16@example.org
# 401  Stephanie Sullivan       dennisbell@example.com
#
#                                        id   user_lat   user_long
# 0    152e8e72-c295-4a60-9249-63d6aba3be23 -53.697738  136.691290
# 1    1b4839eb-7c8a-4598-9ce6-a4e2cb9e8f8f  77.878758  115.675834
# 2    f8f0a8f5-599a-4874-bef5-a0d33b1f6467  -1.759962   56.150637
# 3    975185b7-0919-4726-b132-c83e95010e53 -80.817103   27.331433
# 4    9701fe9f-e2c5-4ab4-bcd9-ee1c38fc2c71 -60.219738  -65.977175
# ..                                    ...        ...         ...
# 397  5bad2a20-80f8-4706-b284-599433d3e456  21.386186   60.731803
# 398  02cb64d2-9a73-4b18-bf26-9648a4516d4f  68.515758 -172.603559
# 399  df7c9f90-78a0-49b0-abdb-af10595b6e86 -85.743940   38.104181
# 400  4b62f0d4-6ae2-4e91-aae9-0d01fa5862cb  18.440468 -176.054865
# 401  e356a22b-45a6-450d-a745-b6ad659af4ae -46.208761 -169.630039
#
# [402 rows x 5 columns]

# %%
user_ratings_data = pd.read_sql('SELECT * FROM dive_site_rating', con=engine)

user_ratings_data
# Out:
#           id  dive_site_id  rating                               user_id
# 0          1          3071     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 1          4          2845     2.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 2          5          3839     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 3          6          4079     3.0  f8f0a8f5-599a-4874-bef5-a0d33b1f6467
# 4          7          1348     4.0  f8f0a8f5-599a-4874-bef5-a0d33b1f6467
# ...      ...           ...     ...                                   ...
# 23213  23217          3333     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23214  23218          1034     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23215  23219          3696     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23216  23220          3101     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23217  23221          2140     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
#
# [23218 rows x 4 columns]

# %%
user_ratings_data['user_id'][0]
# Out:
# UUID('152e8e72-c295-4a60-9249-63d6aba3be23')

# %%
import uuid

# Define the target user_id as a UUID object
target_user_id = uuid.UUID('152e8e72-c295-4a60-9249-63d6aba3be23')

# Filter rows by user_id
user_ratings = user_ratings_data[user_ratings_data['user_id'] == target_user_id]

user_ratings
# Out:
#           id  dive_site_id  rating                               user_id
# 0          1          3071     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 1          4          2845     2.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 2          5          3839     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23209  23213          3674     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23210  23214           231     1.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23211  23215          3581     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23212  23216           808     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23213  23217          3333     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23214  23218          1034     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23215  23219          3696     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23216  23220          3101     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23217  23221          2140     5.0  152e8e72-c295-4a60-9249-63d6aba3be23

# %%
# This are all the features columns we use for recommending
# it wouldnt make sense to include geodata here. If a user rates one dive site in Australia and one in America, we would calculate the mean of the geodata, which would lead us ending up in Africa or Europa - nonsense
feature_columns = categories['name'].tolist() + animals['name'].tolist()


# for the given user, extract all ratings and item profiles

def get_item_profile_of_user(user_id):
    """
    This function returns a list of item profiles and a list of ratings for the given user_id.
    """
    user_ratings = user_ratings_data[user_ratings_data['user_id'] == user_id]

    print(f"User with ID {user_id} has rated {len(user_ratings)} dive sites.")
    print(user_ratings)

    item_profiles = []
    ratings = []

    for index, row in user_ratings.iterrows():
        
        rating = row['rating']
        dive_site_id = row['dive_site_id']
        item_profile = converted_dive_sites[converted_dive_sites['id'] == dive_site_id][feature_columns].to_numpy().flatten()
        item_profiles.append(item_profile)
        ratings.append(rating)

    ratings = np.array(ratings)
    item_profiles = np.array(item_profiles)

    # Create a DataFrame for better interpretability
    item_profiles = pd.DataFrame(item_profiles, columns=feature_columns)

    return ratings, item_profiles


# TEST

# Define the target user_id as a UUID object
target_user_id = uuid.UUID('152e8e72-c295-4a60-9249-63d6aba3be23')

# get the item profiles of user with id 1
ratings, item_profiles = get_item_profile_of_user(target_user_id)

# check if the item profiles are correct
assert np.array_equal(ratings, user_ratings_data[user_ratings_data['user_id'] == target_user_id]['rating'].to_numpy())

i = 0
for row in user_ratings_data[user_ratings_data['user_id'] == target_user_id].to_numpy():
    dive_site_id = row[1] # get the dive site id
    item_profile = converted_dive_sites[converted_dive_sites['id'] == dive_site_id][feature_columns].to_numpy().flatten() # get the item profile of that id
    assert np.array_equal(item_profile, item_profiles.iloc[i].to_numpy())
    i += 1
# Out:
# User with ID 152e8e72-c295-4a60-9249-63d6aba3be23 has rated 12 dive sites.
#           id  dive_site_id  rating                               user_id
# 0          1          3071     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 1          4          2845     2.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 2          5          3839     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23209  23213          3674     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23210  23214           231     1.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23211  23215          3581     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23212  23216           808     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23213  23217          3333     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23214  23218          1034     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23215  23219          3696     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23216  23220          3101     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23217  23221          2140     5.0  152e8e72-c295-4a60-9249-63d6aba3be23

# %%
def generate_user_profile(ratings, item_profiles):
    """
    This function generates a user profile based on the given ratings and item profiles.
    """
    user_profile = None

    item_profiles = item_profiles.to_numpy()

    # option 1
    # new_ratings = ratings # normal ratings

    # option 2
    #new_ratings = ratings - ratings.mean() # mean ratings

    # option 3
    new_ratings = ratings - 2.5

    for i in range(len(item_profiles)):
        
        if user_profile is None:
            user_profile = new_ratings[i] * item_profiles[i]
        else:
            user_profile += new_ratings[i] * item_profiles[i]

    user_profile = user_profile / len(item_profiles)

    user_profile = pd.DataFrame(user_profile.reshape(1, user_profile.shape[0]), columns=feature_columns)
        
    return user_profile



# TEST
ratings, item_profiles = get_item_profile_of_user(target_user_id)
user_profile = generate_user_profile(ratings, item_profiles)

ratings = ratings - 2.5
# Check if the user profile is correct. It should be the average of the item profiles weighted by the ratings
non_zero_features = user_profile.loc[:, (user_profile != 0).any(axis=0)]

expected_user_profile = np.zeros(len(feature_columns))
for i in range(len(item_profiles)):
    expected_user_profile += ratings[i] * item_profiles.iloc[i].to_numpy()

expected_user_profile = expected_user_profile / len(item_profiles)

assert np.array_equal(expected_user_profile, user_profile.to_numpy().flatten())

for column in user_profile.columns:
    print(f"{column}: {user_profile[column].values[0]}") #, Expected {expected_user_profile[feature_columns.index(column)]}")


def normalize_user_profile(user_profile):
    """
    Normalize the user profile so that the highest values become 1,
    the lowest become 0, and neutral (0) values remain 0.
    """
    user_profile_array = user_profile.to_numpy().flatten()
    
    max_val = np.max(user_profile_array)
    min_val = np.min(user_profile_array)
    
    # Avoid division by zero
    if max_val == min_val:
        return user_profile  # No meaningful scaling possible
    
    # Normalize values to [0, 1]
    normalized_array = (user_profile_array - min_val) / (max_val - min_val)
    
    # Retain 0s for unimportant features
    normalized_array[user_profile_array == 0] = 0
    
    # Convert back to DataFrame
    normalized_profile = pd.DataFrame(normalized_array.reshape(1, -1), columns=user_profile.columns)
    return normalized_profile

# TEST
normalized_user_profile = normalize_user_profile(user_profile)

# Check if the normalization is correct
assert np.all(normalized_user_profile >= 0)
assert np.all(normalized_user_profile <= 1)

for column in normalized_user_profile.columns:
    print(f"{column}: {normalized_user_profile[column].values[0]}")


def add_geodata_to_user_profile(user_profile, user_id):
    """
    This function adds the user's geodata to the user profile.
    """

    user_lat = user.loc[user['id'] == user_id, 'user_lat'].values
    user_long = user.loc[user['id'] == user_id, 'user_long'].values

    # Scale the user's geodata between 0 and 1
    lat_min = -90
    lat_max = 90

    long_min = -180
    long_max = 180

    user_lat_scaled = (user_lat - lat_min) / (lat_max - lat_min)
    user_long_scaled = (user_long - long_min) / (long_max - long_min)

    # Add the scaled geodata to the user profile 
    # TODO:
    user_profile['user_lat_scaled'] = user_lat_scaled
    user_profile['user_long_scaled'] = user_long_scaled

    return user_profile
# Out:
# User with ID 152e8e72-c295-4a60-9249-63d6aba3be23 has rated 12 dive sites.
#           id  dive_site_id  rating                               user_id
# 0          1          3071     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 1          4          2845     2.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 2          5          3839     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23209  23213          3674     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23210  23214           231     1.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23211  23215          3581     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23212  23216           808     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23213  23217          3333     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23214  23218          1034     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23215  23219          3696     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23216  23220          3101     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23217  23221          2140     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# Fjord: 0.0
# Muck: 0.0
# Sea Loch: 0.0
# Spring: 0.0
# Pool: 0.375
# Archaeological: 0.0
# Quarry: 0.0
# Pinnacle: 0.0
# Cavern: 0.0
# River: 0.0
# Sandy bottom: 0.0
# Lake: 0.5416666666666666
# Ocean: 0.75
# Channel: 0.0
# Cave: 0.20833333333333334
# Drift: 0.0
# Wall: 0.5416666666666666
# Beach: 0.0
# Reef: 0.3333333333333333
# Wreck: 0.08333333333333333
# Spider Crab: 0.0
# Ribbon Eel: 0.0
# Chondrichthyes: 0.0
# Jellyfish: 0.0
# Moray Eel: 0.125
# Requiem Sharks: 0.0
# Stingray: 0.0
# Emperor Fish: 0.0
# Dolphins: 0.0
# Lizardfish: 0.0
# Ray: 0.0
# Trumpetfish Pipefish: 0.0
# Eel Blennies: 0.0
# Sponges: 0.0
# Skates: 0.0
# Sicyoniid Shrimp: 0.0
# Serpulid Worms: 0.0
# Eel: 0.0
# Coral: 0.0
# Sculpins: 0.0
# Weedy Sea Dragon: 0.0
# Wobbegong Shark: 0.0
# Longfin: 0.0
# Carpet Sharks: 0.0
# Bullhead Sharks: 0.0
# Bigeyes: 0.0
# Sand Tiger Shark: 0.0
# Flatheads: 0.0
# Prawns: 0.0
# Hermit Crab: 0.0
# Rabbitfish: 0.0
# Fanworms: 0.0
# Eared Seals: 0.0
# Sea Sponges: 0.0
# Feather Stars: 0.0
# Dugongs: 0.0
# Carps And Minnows: 0.0
# Razor Clams: 0.0
# Poachers: 0.0
# Cownose Ray: 0.0
# Manta: 0.0
# Juvenile Fish Macro: 0.0
# Chaetonotids: 0.0
# Irciniid Sponges: 0.0
# Blennies: 0.0
# Nurse Shark: 0.0
# Soldierfish: 0.0
# Lung Snails: 0.0
# Chubs: 0.0
# Myrrhine Fish: 0.0
# Sergestid Shrimp: 0.0
# Glassfish: 0.0
# Aegirids: 0.0
# Soft Coral: 0.0
# Stylasteridae: 0.0
# Crambe Fish: 0.0
# Bonytongues: 0.0
# Oysters: 0.0
# Rudd: 0.0
# Placosponges: 0.0
# Baars: 0.0
# Roncadores: 0.0
# Manatee Dugong: 0.0
# Seahorse Family: 0.0
# Flounder: 0.0
# Eagle Ray: 0.0
# Sea Anemone: 0.0
# Sea Turtle: 0.0
# Jackfish: 0.0
# Grouper: -0.125
# Dorid Nudibranchs: 0.0
# Scorpionfish: 0.0
# Mackerel: 0.0
# Mantis Shrimp: 0.0
# Coral Trout: 0.0
# Snaper: 0.0
# Boxfish: 0.0
# Trumpetfish: 0.0
# Congers: 0.0
# Baracuda: 0.0
# Saddleback Fish: 0.0
# Angelfish: 0.0
# Parrotfish: 0.0
# Goatfish: 0.0
# Damselfish: -0.125
# Cuttlefish: 0.0
# Butterflyfish: 0.0
# Gobies: 0.0
# Grunts: 0.0
# Wrasse: 0.0
# Mushroom Corals: 0.0
# Cleaner Shrimp: 0.0
# Mola Fish: 0.0
# Hawkfish: 0.0
# Cardinalfish: 0.0
# Saber-Toothed Blennies: 0.0
# Leatherjacket Fish: 0.0
# Tigerfish: 0.0
# Carpet Anemones: 0.0
# Squirrelfish: 0.0
# Ghostpipefish: 0.0
# Stonefish: 0.0
# Surgeonfish: 0.0
# Pufferfish: 0.0
# Porcelain Crabs: 0.0
# Tropical Anglerfish: 0.0
# Pencil Fish: 0.0
# Cone Snails: 0.0
# Seaslug: 0.0
# Manta Ray: 0.0
# Fireworms: 0.0
# Octopus: 0.0
# Flatfish: 0.0
# Porgies: 0.0
# Halfbeaks: 0.0
# Frogfish: 0.0
# Squid: 0.0
# Paddlefish: 0.0
# Salmon Family: 0.0
# Needlefish: 0.0
# Pistol Shrimp: 0.0
# Staghorn Coral: 0.0
# Stony Corals: 0.0
# Sole: 0.0
# Lobophyllia Corals: 0.0
# Seastars: 0.0
# Box Crabs: 0.0
# Sea Cucumber: 0.0
# Sea Urchin: 0.0
# Cowfish: 0.0
# Boxfish Pufferfish: 0.0
# Crab: 0.0
# Drums: 0.0
# Starfish: 0.0
# Cod: 0.0
# Lobster: 0.0
# Sunfish: 0.0
# Pike: 0.0
# Pipefish: 0.0
# Tethys Fish: 0.0
# Pencilfish: 0.0
# Cusk Eels: 0.0
# Remora: 0.0
# Swimming Crabs: 0.0
# Nudibranch: 0.0
# Cancer Crabs: 0.0
# Moon Jellyfish: 0.0
# Gorgonian Corals: 0.0
# Brain Coral: 0.0
# Rockfish: 0.0
# Tarpon: 0.0
# Flying Gurnard: 0.0
# Oplophid Shrimp: 0.0
# Acanthephyrid Shrimp: 0.0
# Round Stingrays: 0.0
# Whaleshark: 0.0
# Hawksbill Turtle: 0.0
# Crown-Of-Thorns Starfish: 0.0
# Elapids: 0.0
# Bannerfish: 0.0
# Perch Family: 0.0
# Basslets: 0.0
# Lates: 0.0
# Dendrophylliid Corals: 0.0
# Guitarfish: 0.0
# Numbfish: 0.0
# Cycloteuthid Squids: 0.0
# Angelshark: 0.0
# Whitetip Reef Shark: 0.0
# Seahorse: 0.0
# Cockatoo Cuttlefish: 0.0
# Berycids: 0.0
# Basket Star: 0.0
# Hakes: 0.20833333333333334
# Cyttid Fish: 0.0
# Mullet: 0.0
# Fish: 0.0
# Bolinopsid Fishes: 0.0
# Sea Pens: 0.0
# Shrimp: 0.0
# Crawfish: 0.0
# Blenny: 0.0
# Bonefish: 0.0
# Land Hermit Crabs: 0.0
# Horseshoe Crabs: 0.0
# Flatworm: 0.0
# Sweeper Fish: 0.0
# Sixgill Sharks: 0.0
# Spirastrellid Sponges: 0.0
# Brittle Star: 0.0
# Pinnae: 0.0
# Rhinid Fish: 0.0
# Giant Cuttlefish: 0.0
# Sea Snake: 0.0
# Lionfish: 0.0
# Boobies And Gannets: 0.0
# Frigatebirds: 0.0
# Dwarf Sculpins: 0.0
# Napoleon Fish: 0.0
# Silvertip Shark: 0.0
# Blacktip Shark: 0.0
# Mobula Ray: 0.0
# Salpe: 0.0
# Hammerhead Shark: 0.0
# Leaffish: 0.0
# Turtle: 0.0
# Weever Fish: 0.0
# Bitterlings: 0.0
# Sea Squirts: 0.0
# Sleeper Gobies: 0.0
# Firefly Squids: 0.0
# Surfperches: 0.0
# Toadfish: 0.0
# Jawfish: 0.0
# Cockles: 0.0
# Lemon Shark: 0.0
# Tiger Shark: 0.0
# Bream: 0.0
# Catfish: 0.0
# Gray Reef Shark: 0.0
# Bluering Octopus: 0.0
# Seal: 0.0
# Round Rays: 0.0
# Trout: 0.0
# Common Dolphin: 0.0
# Electric Ray: 0.0
# Eel-Tailed Catfish: 0.0
# Fire Corals: 0.0
# Sea Fan: 0.0
# Brown Algae: 0.0
# Clionid Sponges: 0.0
# Scallops: 0.0
# Dogfish: 0.0
# Cod Family: 0.0
# Polybiid Eels: 0.0
# Eledonid Fish: 0.0
# Cormorant: 0.0
# John Dory: 0.0
# Antarctic Rockcods: 0.0
# Squat Lobster: 0.0
# Megalodon: 0.0
# Oceanic Whitetip Shark: 0.0
# Sea Worms: 0.0
# Cichlids: 0.0
# Luidia: 0.0
# Houndsharks: 0.0
# Stargazers: 0.0
# Dragonets: 0.0
# Bobtail Squid: 0.0
# Coral Reef Fish: 0.0
# Black Coral: 0.0
# Cowries: 0.0
# Manatee: 0.0
# Nereid Worms: 0.0
# Eelpouts: 0.0
# Catsharks: 0.0
# Cup Corals: 0.0
# Herring: 0.0
# Dottybacks: 0.0
# Lumpfish: 0.0
# Sunflower Stars: 0.0
# Zebra Shark: 0.0
# Carpet Corals: 0.0
# Silversides: 0.0
# Ophidiasteridae: 0.0
# Argonauts: 0.0
# Bubblers: 0.0
# Sea Stars: 0.0
# Mushroom Jellyfish: 0.0
# Plagusiid Crabs: 0.0
# Janolids: 0.0
# Tube-Dwelling Anemones: 0.0
# Clingfish: 0.0
# Cassididae: 0.0
# Metridid Fish: 0.0
# Pea Crabs: 0.0
# Deepsea Smelts: 0.0
# Snook: 0.0
# Cow Sharks: 0.0
# Opah: 0.0
# Goneplacid Crabs: 0.0
# Iphimediid Fishes: 0.0
# Abalone: 0.0
# Sea Hare: 0.0
# Honeycomb Moray: 0.0
# Sturgeon: 0.0
# Soleidae: 0.0
# Leptastrea Fish: 0.0
# Organ-Pipe Corals: 0.0
# Box Jellyfish: 0.0
# Feather Duster Worms: 0.0
# Diphyid Fish: 0.0
# Sarcophagidae: 0.0
# Rorquals: 0.0
# Moon Snails: 0.0
# Bamboo Shark: 0.0
# Triplefin Blennies: 0.0
# Flying Fish: 0.0
# Moonyfish: 0.0
# Mud Crabs: 0.0
# Argentines: 0.0
# Pricklebacks: 0.0
# Terebellid Worms: 0.0
# Olindiid Fish: 0.0
# Pillow Sponges: 0.0
# Kelp: 0.0
# Sea Spiders: 0.0
# Corynid Fish: 0.0
# Top Snails: 0.0
# Thorids: 0.0
# Bonelliid Rays: 0.0
# Clathrinid Eels: 0.0
# Cray Fish: 0.0
# Anchovies: 0.0
# Chondrosidae: 0.0
# Stylid Fish: 0.0
# Pandalid Shrimp: 0.0
# Heart Urchins: 0.0
# Mussels: 0.0
# Whelks: 0.0
# Mackerel Sharks: 0.0
# Corallimorphs: 0.0
# Tripedaliid Jellyfish: 0.0
# Dartfish: 0.0
# Snipefish: 0.0
# Chimeras: 0.0
# Bullhead Sculpins: 0.0
# Dreissenid Mussels: 0.0
# Sharks: 0.0
# Sunfish Mola Mola: 0.0
# Sealion: 0.0
# Wolf Fish: 0.0
# Eelgrass Family: 0.0
# Glaucostegid Fishes: 0.0
# Livebearers: 0.0
# Acorn Barnacles: 0.0
# Tuna: 0.0
# Giant Moray: 0.0
# Garden Eels: 0.0
# Ovalipids: 0.0
# Gorgonian Fan: 0.0
# Snapping Shrimp: 0.0
# Bottlenose Dolphin: 0.0
# Sweetlips: 0.0
# Redfish: 0.0
# Clam: 0.0
# Loggerhead Turtle: 0.0
# Leopard Shark: 0.0
# Rocklings: 0.0
# Mobula: 0.0
# Plerogyrid Fishes: 0.0
# Green Algae: 0.0
# Guitar Shark: 0.0
# Minke Whale: 0.0
# Humpback Whale: 0.0
# Ghost Crabs: 0.0
# Sand Lances: 0.0
# Perch: 0.0
# Swordfish: 0.0
# Goldsinny Wrasse: 0.0
# Porpoises: 0.0
# Giant Silversides: 0.0
# Sea Catfish: 0.0
# Carp: 0.0
# Anemone Fish: 0.0
# Ornate Ghost Pipefish: 0.0
# Leatherback Turtles: 0.0
# Humphead Parrotfish: 0.0
# Common Stingray: 0.0
# Seabream: 0.0
# Amberjack: 0.0
# Kingfish: 0.0
# Common Octopus: 0.0
# Green Turtle: 0.0
# Bull Ray: 0.0
# Yellowtail: 0.0
# Drum Fish: 0.0
# Green Turtles: 0.0
# Whitemouth Moray: 0.0
# Muray: 0.0
# Bull Shark: 0.0
# Crappie: 0.0
# Bass: 0.0
# Bluegill: 0.0
# Mako Shark: 0.0
# Blue Shark: 0.0
# Piranha: 0.0
# Tilefish: 0.0
# Fusilier: 0.0
# Characins: 0.0
# Sea Otter: 0.0
# Pollack: 0.0
# Skeleton Shrimp: 0.0
# Sargassum: 0.0
# King Crabs: 0.0
# Spurge Family: 0.0
# Calliopiid Snails: 0.0
# Copepods: 0.0
# Calanoid Copepods: 0.0
# Krill: 0.0
# Scolecitrichids: 0.0
# Garibaldi: 0.0
# Sheepshead: 0.0
# Emperors: 0.0
# Thresher Shark: 0.0
# Yellowfins Tuna: 0.0
# Trevally: 0.0
# Blue-Fin Damselfish: 0.0
# Sardines: 0.0
# Walleye: 0.0
# Pipehorse: 0.0
# Great White Shark: 0.0
# Pork Fish: 0.0
# Spadefish: 0.0
# Trunkfish: 0.0
# Snook Fish: 0.0
# Elkhorns: 0.0
# Tge Biggest Brain Corals: 0.0
# Tench: 0.0
# Anemones: 0.0
# Sandperch: 0.0
# Dentex: 0.0
# Yellow Goat Fish: 0.0
# Bluehead: 0.0
# Silkfish: 0.0
# Spiny Sharks: 0.0
# False Hammerhead Sharks: 0.0
# Spinner Dolphin: 0.0
# Lanternsharks: 0.0
# Marbled Electric Ray: 0.0
# Conger Eel: 0.0
# Anthias: 0.0
# Salmon: 0.0
# Krebs: 0.0
# Barsch: 0.0
# Schleie: 0.0
# Egli: 0.0
# Hecht: 0.0
# Wide Range Of Reef Fish: 0.0
# Atlantic Ray: 0.0
# Sole Fish: 0.0
# Pygmy Pipehorse: 0.0
# Rhinophias: 0.0
# Macro: 0.0
# Goby: 0.0
# Gorgonians: 0.0
# Red Coral: 0.0
# Aborre: 0.0
# Spotted Eagle Ray: 0.0
# Mandarinfish: 0.0
# Snoek: 0.0
# Salema: 0.0
# Reef Fish: 0.0
# Morena: 0.0
# Octos: 0.0
# Mere: 0.0
# Samarid Fish: 0.0
# Sea Moth: 0.0
# Eunicid Worms: 0.0
# Bowmouth: 0.0
# Oceanic Blacktip Shark: 0.0
# Minnow: 0.0
# Dusky Shark: 0.0
# Acropora: 0.0
# Rhopalonematidae: 0.0
# Seagrass: 0.0
# Flamboyant Cuttlefish: 0.0
# Bluebottle Jellyfish: 0.0
# Reef Shark: 0.0
# Filefish: 0.0
# Porcupinefish: 0.0
# Paperfish: 0.0
# Damsel: 0.0
# Seabass: 0.0
# Limpets: 0.0
# Dendronotid Nudibranchs: 0.0
# Oweniid Worms: 0.0
# Hamlet: 0.0
# Skorpion: 0.0
# Crabs - Harbour: 0.0
# Billfish: 0.0
# Ragged Tooth Sharks: 0.0
# Dromiid Crabs: 0.0
# Snoekbaars: 0.0
# Paling: 0.0
# Kreeft: 0.0
# Biemnid Fish: 0.0
# Valonia Algae: 0.0
# White Tip Sharks: 0.0
# Wonderpus: 0.0
# Dotto: 0.0
# Rainbow Wrasse: 0.0
# Tautog: 0.0
# Sea Raven: 0.0
# Tripplefins: 0.0
# Heteractis Anemones: 0.0
# Rocketfishes: 0.0
# Serpent Eel: 0.0
# Tree Dorids: 0.0
# Desmacidids: 0.0
# Fjord: 0.0
# Muck: 0.0
# Sea Loch: 0.0
# Spring: 0.0
# Pool: 0.5714285714285714
# Archaeological: 0.0
# Quarry: 0.0
# Pinnacle: 0.0
# Cavern: 0.0
# River: 0.0
# Sandy bottom: 0.0
# Lake: 0.7619047619047619
# Ocean: 1.0
# Channel: 0.0
# Cave: 0.380952380952381
# Drift: 0.0
# Wall: 0.7619047619047619
# Beach: 0.0
# Reef: 0.5238095238095238
# Wreck: 0.23809523809523808
# Spider Crab: 0.0
# Ribbon Eel: 0.0
# Chondrichthyes: 0.0
# Jellyfish: 0.0
# Moray Eel: 0.2857142857142857
# Requiem Sharks: 0.0
# Stingray: 0.0
# Emperor Fish: 0.0
# Dolphins: 0.0
# Lizardfish: 0.0
# Ray: 0.0
# Trumpetfish Pipefish: 0.0
# Eel Blennies: 0.0
# Sponges: 0.0
# Skates: 0.0
# Sicyoniid Shrimp: 0.0
# Serpulid Worms: 0.0
# Eel: 0.0
# Coral: 0.0
# Sculpins: 0.0
# Weedy Sea Dragon: 0.0
# Wobbegong Shark: 0.0
# Longfin: 0.0
# Carpet Sharks: 0.0
# Bullhead Sharks: 0.0
# Bigeyes: 0.0
# Sand Tiger Shark: 0.0
# Flatheads: 0.0
# Prawns: 0.0
# Hermit Crab: 0.0
# Rabbitfish: 0.0
# Fanworms: 0.0
# Eared Seals: 0.0
# Sea Sponges: 0.0
# Feather Stars: 0.0
# Dugongs: 0.0
# Carps And Minnows: 0.0
# Razor Clams: 0.0
# Poachers: 0.0
# Cownose Ray: 0.0
# Manta: 0.0
# Juvenile Fish Macro: 0.0
# Chaetonotids: 0.0
# Irciniid Sponges: 0.0
# Blennies: 0.0
# Nurse Shark: 0.0
# Soldierfish: 0.0
# Lung Snails: 0.0
# Chubs: 0.0
# Myrrhine Fish: 0.0
# Sergestid Shrimp: 0.0
# Glassfish: 0.0
# Aegirids: 0.0
# Soft Coral: 0.0
# Stylasteridae: 0.0
# Crambe Fish: 0.0
# Bonytongues: 0.0
# Oysters: 0.0
# Rudd: 0.0
# Placosponges: 0.0
# Baars: 0.0
# Roncadores: 0.0
# Manatee Dugong: 0.0
# Seahorse Family: 0.0
# Flounder: 0.0
# Eagle Ray: 0.0
# Sea Anemone: 0.0
# Sea Turtle: 0.0
# Jackfish: 0.0
# Grouper: 0.0
# Dorid Nudibranchs: 0.0
# Scorpionfish: 0.0
# Mackerel: 0.0
# Mantis Shrimp: 0.0
# Coral Trout: 0.0
# Snaper: 0.0
# Boxfish: 0.0
# Trumpetfish: 0.0
# Congers: 0.0
# Baracuda: 0.0
# Saddleback Fish: 0.0
# Angelfish: 0.0
# Parrotfish: 0.0
# Goatfish: 0.0
# Damselfish: 0.0
# Cuttlefish: 0.0
# Butterflyfish: 0.0
# Gobies: 0.0
# Grunts: 0.0
# Wrasse: 0.0
# Mushroom Corals: 0.0
# Cleaner Shrimp: 0.0
# Mola Fish: 0.0
# Hawkfish: 0.0
# Cardinalfish: 0.0
# Saber-Toothed Blennies: 0.0
# Leatherjacket Fish: 0.0
# Tigerfish: 0.0
# Carpet Anemones: 0.0
# Squirrelfish: 0.0
# Ghostpipefish: 0.0
# Stonefish: 0.0
# Surgeonfish: 0.0
# Pufferfish: 0.0
# Porcelain Crabs: 0.0
# Tropical Anglerfish: 0.0
# Pencil Fish: 0.0
# Cone Snails: 0.0
# Seaslug: 0.0
# Manta Ray: 0.0
# Fireworms: 0.0
# Octopus: 0.0
# Flatfish: 0.0
# Porgies: 0.0
# Halfbeaks: 0.0
# Frogfish: 0.0
# Squid: 0.0
# Paddlefish: 0.0
# Salmon Family: 0.0
# Needlefish: 0.0
# Pistol Shrimp: 0.0
# Staghorn Coral: 0.0
# Stony Corals: 0.0
# Sole: 0.0
# Lobophyllia Corals: 0.0
# Seastars: 0.0
# Box Crabs: 0.0
# Sea Cucumber: 0.0
# Sea Urchin: 0.0
# Cowfish: 0.0
# Boxfish Pufferfish: 0.0
# Crab: 0.0
# Drums: 0.0
# Starfish: 0.0
# Cod: 0.0
# Lobster: 0.0
# Sunfish: 0.0
# Pike: 0.0
# Pipefish: 0.0
# Tethys Fish: 0.0
# Pencilfish: 0.0
# Cusk Eels: 0.0
# Remora: 0.0
# Swimming Crabs: 0.0
# Nudibranch: 0.0
# Cancer Crabs: 0.0
# Moon Jellyfish: 0.0
# Gorgonian Corals: 0.0
# Brain Coral: 0.0
# Rockfish: 0.0
# Tarpon: 0.0
# Flying Gurnard: 0.0
# Oplophid Shrimp: 0.0
# Acanthephyrid Shrimp: 0.0
# Round Stingrays: 0.0
# Whaleshark: 0.0
# Hawksbill Turtle: 0.0
# Crown-Of-Thorns Starfish: 0.0
# Elapids: 0.0
# Bannerfish: 0.0
# Perch Family: 0.0
# Basslets: 0.0
# Lates: 0.0
# Dendrophylliid Corals: 0.0
# Guitarfish: 0.0
# Numbfish: 0.0
# Cycloteuthid Squids: 0.0
# Angelshark: 0.0
# Whitetip Reef Shark: 0.0
# Seahorse: 0.0
# Cockatoo Cuttlefish: 0.0
# Berycids: 0.0
# Basket Star: 0.0
# Hakes: 0.380952380952381
# Cyttid Fish: 0.0
# Mullet: 0.0
# Fish: 0.0
# Bolinopsid Fishes: 0.0
# Sea Pens: 0.0
# Shrimp: 0.0
# Crawfish: 0.0
# Blenny: 0.0
# Bonefish: 0.0
# Land Hermit Crabs: 0.0
# Horseshoe Crabs: 0.0
# Flatworm: 0.0
# Sweeper Fish: 0.0
# Sixgill Sharks: 0.0
# Spirastrellid Sponges: 0.0
# Brittle Star: 0.0
# Pinnae: 0.0
# Rhinid Fish: 0.0
# Giant Cuttlefish: 0.0
# Sea Snake: 0.0
# Lionfish: 0.0
# Boobies And Gannets: 0.0
# Frigatebirds: 0.0
# Dwarf Sculpins: 0.0
# Napoleon Fish: 0.0
# Silvertip Shark: 0.0
# Blacktip Shark: 0.0
# Mobula Ray: 0.0
# Salpe: 0.0
# Hammerhead Shark: 0.0
# Leaffish: 0.0
# Turtle: 0.0
# Weever Fish: 0.0
# Bitterlings: 0.0
# Sea Squirts: 0.0
# Sleeper Gobies: 0.0
# Firefly Squids: 0.0
# Surfperches: 0.0
# Toadfish: 0.0
# Jawfish: 0.0
# Cockles: 0.0
# Lemon Shark: 0.0
# Tiger Shark: 0.0
# Bream: 0.0
# Catfish: 0.0
# Gray Reef Shark: 0.0
# Bluering Octopus: 0.0
# Seal: 0.0
# Round Rays: 0.0
# Trout: 0.0
# Common Dolphin: 0.0
# Electric Ray: 0.0
# Eel-Tailed Catfish: 0.0
# Fire Corals: 0.0
# Sea Fan: 0.0
# Brown Algae: 0.0
# Clionid Sponges: 0.0
# Scallops: 0.0
# Dogfish: 0.0
# Cod Family: 0.0
# Polybiid Eels: 0.0
# Eledonid Fish: 0.0
# Cormorant: 0.0
# John Dory: 0.0
# Antarctic Rockcods: 0.0
# Squat Lobster: 0.0
# Megalodon: 0.0
# Oceanic Whitetip Shark: 0.0
# Sea Worms: 0.0
# Cichlids: 0.0
# Luidia: 0.0
# Houndsharks: 0.0
# Stargazers: 0.0
# Dragonets: 0.0
# Bobtail Squid: 0.0
# Coral Reef Fish: 0.0
# Black Coral: 0.0
# Cowries: 0.0
# Manatee: 0.0
# Nereid Worms: 0.0
# Eelpouts: 0.0
# Catsharks: 0.0
# Cup Corals: 0.0
# Herring: 0.0
# Dottybacks: 0.0
# Lumpfish: 0.0
# Sunflower Stars: 0.0
# Zebra Shark: 0.0
# Carpet Corals: 0.0
# Silversides: 0.0
# Ophidiasteridae: 0.0
# Argonauts: 0.0
# Bubblers: 0.0
# Sea Stars: 0.0
# Mushroom Jellyfish: 0.0
# Plagusiid Crabs: 0.0
# Janolids: 0.0
# Tube-Dwelling Anemones: 0.0
# Clingfish: 0.0
# Cassididae: 0.0
# Metridid Fish: 0.0
# Pea Crabs: 0.0
# Deepsea Smelts: 0.0
# Snook: 0.0
# Cow Sharks: 0.0
# Opah: 0.0
# Goneplacid Crabs: 0.0
# Iphimediid Fishes: 0.0
# Abalone: 0.0
# Sea Hare: 0.0
# Honeycomb Moray: 0.0
# Sturgeon: 0.0
# Soleidae: 0.0
# Leptastrea Fish: 0.0
# Organ-Pipe Corals: 0.0
# Box Jellyfish: 0.0
# Feather Duster Worms: 0.0
# Diphyid Fish: 0.0
# Sarcophagidae: 0.0
# Rorquals: 0.0
# Moon Snails: 0.0
# Bamboo Shark: 0.0
# Triplefin Blennies: 0.0
# Flying Fish: 0.0
# Moonyfish: 0.0
# Mud Crabs: 0.0
# Argentines: 0.0
# Pricklebacks: 0.0
# Terebellid Worms: 0.0
# Olindiid Fish: 0.0
# Pillow Sponges: 0.0
# Kelp: 0.0
# Sea Spiders: 0.0
# Corynid Fish: 0.0
# Top Snails: 0.0
# Thorids: 0.0
# Bonelliid Rays: 0.0
# Clathrinid Eels: 0.0
# Cray Fish: 0.0
# Anchovies: 0.0
# Chondrosidae: 0.0
# Stylid Fish: 0.0
# Pandalid Shrimp: 0.0
# Heart Urchins: 0.0
# Mussels: 0.0
# Whelks: 0.0
# Mackerel Sharks: 0.0
# Corallimorphs: 0.0
# Tripedaliid Jellyfish: 0.0
# Dartfish: 0.0
# Snipefish: 0.0
# Chimeras: 0.0
# Bullhead Sculpins: 0.0
# Dreissenid Mussels: 0.0
# Sharks: 0.0
# Sunfish Mola Mola: 0.0
# Sealion: 0.0
# Wolf Fish: 0.0
# Eelgrass Family: 0.0
# Glaucostegid Fishes: 0.0
# Livebearers: 0.0
# Acorn Barnacles: 0.0
# Tuna: 0.0
# Giant Moray: 0.0
# Garden Eels: 0.0
# Ovalipids: 0.0
# Gorgonian Fan: 0.0
# Snapping Shrimp: 0.0
# Bottlenose Dolphin: 0.0
# Sweetlips: 0.0
# Redfish: 0.0
# Clam: 0.0
# Loggerhead Turtle: 0.0
# Leopard Shark: 0.0
# Rocklings: 0.0
# Mobula: 0.0
# Plerogyrid Fishes: 0.0
# Green Algae: 0.0
# Guitar Shark: 0.0
# Minke Whale: 0.0
# Humpback Whale: 0.0
# Ghost Crabs: 0.0
# Sand Lances: 0.0
# Perch: 0.0
# Swordfish: 0.0
# Goldsinny Wrasse: 0.0
# Porpoises: 0.0
# Giant Silversides: 0.0
# Sea Catfish: 0.0
# Carp: 0.0
# Anemone Fish: 0.0
# Ornate Ghost Pipefish: 0.0
# Leatherback Turtles: 0.0
# Humphead Parrotfish: 0.0
# Common Stingray: 0.0
# Seabream: 0.0
# Amberjack: 0.0
# Kingfish: 0.0
# Common Octopus: 0.0
# Green Turtle: 0.0
# Bull Ray: 0.0
# Yellowtail: 0.0
# Drum Fish: 0.0
# Green Turtles: 0.0
# Whitemouth Moray: 0.0
# Muray: 0.0
# Bull Shark: 0.0
# Crappie: 0.0
# Bass: 0.0
# Bluegill: 0.0
# Mako Shark: 0.0
# Blue Shark: 0.0
# Piranha: 0.0
# Tilefish: 0.0
# Fusilier: 0.0
# Characins: 0.0
# Sea Otter: 0.0
# Pollack: 0.0
# Skeleton Shrimp: 0.0
# Sargassum: 0.0
# King Crabs: 0.0
# Spurge Family: 0.0
# Calliopiid Snails: 0.0
# Copepods: 0.0
# Calanoid Copepods: 0.0
# Krill: 0.0
# Scolecitrichids: 0.0
# Garibaldi: 0.0
# Sheepshead: 0.0
# Emperors: 0.0
# Thresher Shark: 0.0
# Yellowfins Tuna: 0.0
# Trevally: 0.0
# Blue-Fin Damselfish: 0.0
# Sardines: 0.0
# Walleye: 0.0
# Pipehorse: 0.0
# Great White Shark: 0.0
# Pork Fish: 0.0
# Spadefish: 0.0
# Trunkfish: 0.0
# Snook Fish: 0.0
# Elkhorns: 0.0
# Tge Biggest Brain Corals: 0.0
# Tench: 0.0
# Anemones: 0.0
# Sandperch: 0.0
# Dentex: 0.0
# Yellow Goat Fish: 0.0
# Bluehead: 0.0
# Silkfish: 0.0
# Spiny Sharks: 0.0
# False Hammerhead Sharks: 0.0
# Spinner Dolphin: 0.0
# Lanternsharks: 0.0
# Marbled Electric Ray: 0.0
# Conger Eel: 0.0
# Anthias: 0.0
# Salmon: 0.0
# Krebs: 0.0
# Barsch: 0.0
# Schleie: 0.0
# Egli: 0.0
# Hecht: 0.0
# Wide Range Of Reef Fish: 0.0
# Atlantic Ray: 0.0
# Sole Fish: 0.0
# Pygmy Pipehorse: 0.0
# Rhinophias: 0.0
# Macro: 0.0
# Goby: 0.0
# Gorgonians: 0.0
# Red Coral: 0.0
# Aborre: 0.0
# Spotted Eagle Ray: 0.0
# Mandarinfish: 0.0
# Snoek: 0.0
# Salema: 0.0
# Reef Fish: 0.0
# Morena: 0.0
# Octos: 0.0
# Mere: 0.0
# Samarid Fish: 0.0
# Sea Moth: 0.0
# Eunicid Worms: 0.0
# Bowmouth: 0.0
# Oceanic Blacktip Shark: 0.0
# Minnow: 0.0
# Dusky Shark: 0.0
# Acropora: 0.0
# Rhopalonematidae: 0.0
# Seagrass: 0.0
# Flamboyant Cuttlefish: 0.0
# Bluebottle Jellyfish: 0.0
# Reef Shark: 0.0
# Filefish: 0.0
# Porcupinefish: 0.0
# Paperfish: 0.0
# Damsel: 0.0
# Seabass: 0.0
# Limpets: 0.0
# Dendronotid Nudibranchs: 0.0
# Oweniid Worms: 0.0
# Hamlet: 0.0
# Skorpion: 0.0
# Crabs - Harbour: 0.0
# Billfish: 0.0
# Ragged Tooth Sharks: 0.0
# Dromiid Crabs: 0.0
# Snoekbaars: 0.0
# Paling: 0.0
# Kreeft: 0.0
# Biemnid Fish: 0.0
# Valonia Algae: 0.0
# White Tip Sharks: 0.0
# Wonderpus: 0.0
# Dotto: 0.0
# Rainbow Wrasse: 0.0
# Tautog: 0.0
# Sea Raven: 0.0
# Tripplefins: 0.0
# Heteractis Anemones: 0.0
# Rocketfishes: 0.0
# Serpent Eel: 0.0
# Tree Dorids: 0.0
# Desmacidids: 0.0

# %%
def recommend(input_categories_vector, input_geodata_vector, input_animal_vector, w_cat=1/3, w_geo=1/3, w_animal=1/3, n=10):
    """
    This is a helper function used to recommend dive sites based on input vectors. These input vectors can describe a user or a dive site.     

    CAUTION:
    If we do not have any animal data for a specific dive site, but the w_animal is not 0, we will not consider this dive site for recommendations. (same for categories and geodata)    
    """

    # TODO: Add optional ignore argument if input vectors are a dive spot, ignore this dive spot in the recommendations with index x
    # Precompute dive site vectors
    # they are not ordered by dive_site_id
    dive_site_categories = converted_dive_sites[categories['name']].to_numpy() 
    dive_site_geodata = converted_dive_sites[['lat_scaled', 'long_scaled']].to_numpy()
    dive_site_animals = converted_dive_sites[animals['name']].to_numpy()


    # compute cosine similarities between the user feature vectors and all
    # dive sites in the catalog (except for the query dive site)
    similarities = []

    # iterate over all dive sites
    print("Iterate over all dive sites...")
    for i in range(len(converted_dive_sites)):

        print(f" {i} / {len(converted_dive_sites)}", end="\r")

        similiarity_dict = {}
        similiarity_dict['index'] = i  
        similiarity_dict['animal'] = None
        similiarity_dict['category'] = None
        similiarity_dict['geodata'] = None
        similiarity_dict['combined'] = None

        total_weight = 0
        combined_similarity = 0

        # Category Similarity
        if w_cat != 0:
            other_categories_vector = dive_site_categories[i]
            
            if np.count_nonzero(other_categories_vector) > 0:
                sim_cat = get_cosine_similarity(input_categories_vector, other_categories_vector)
                similiarity_dict['category'] = sim_cat
                combined_similarity += w_cat * sim_cat
                total_weight += w_cat
            else:
                continue

        # Geodata Similarity
        if w_geo != 0:
            other_geodata_vector = dive_site_geodata[i]
            if np.count_nonzero(other_geodata_vector) > 0:
                sim_geo = get_euclidean_similarity(input_geodata_vector, other_geodata_vector)
                similiarity_dict['geodata'] = sim_geo
                combined_similarity += w_geo * sim_geo
                total_weight += w_geo
            else:
                continue

        # Animal Similarity
        if w_animal != 0:
            other_animal_vector = dive_site_animals[i]
            if np.count_nonzero(other_animal_vector) > 0:
                sim_animal = get_cosine_similarity(input_animal_vector, other_animal_vector)
                similiarity_dict['animal'] = sim_animal
                combined_similarity += w_animal * sim_animal
                total_weight += w_animal
            else:
                continue

        # Normalize the similarity by total weight if any feature contributed
        if total_weight != 0:
            combined_similarity /= total_weight
            similiarity_dict['combined'] = combined_similarity
            similarities.append(similiarity_dict)
        

    # sort pairs w.r.t. combined_similarity in descending order (reverse=True)
    similarities = sorted(similarities, key=lambda x: x['combined'], reverse=True)

    # take the top n elements
    recommendations = similarities[:n]

    return recommendations

# %%
def get_recommendations_for_a_user(user_id, w_cat=1/3, w_geo=1/3, w_animal=1/3, n=10):

    """
    This function generates a content based recommendation for a specific user.
    It generates a feature vector for the "ideal dive site" which the given user would like based off his ratings.
    Using this feature vector (which includes category, geodata, animal data) it computes the distance to the dive sites given in the dataset.

    w_cat: weight for the category vector
    w_geo: weight for the geodata (lat_scaled, long_scaled) vector
    w_animal: weight for the animal vector 
    n: number of recommendations to return

    """
    print(f"Generating recommendations for the user with the ID {user_id}...")

    # get the ratings and item profiles of the user
    ratings, item_profiles = get_item_profile_of_user(user_id)

    # generate the user profile
    user_profile = generate_user_profile(ratings, item_profiles)
    # normalize the user profile
    user_profile = normalize_user_profile(user_profile)

    # add the geodata to the user profile
    user_profile = add_geodata_to_user_profile(user_profile, user_id)

    # split up the user profile into the different feature vectors: category, geodata, animal
    # Category vector
    user_categories_vector = user_profile[categories['name']].to_numpy().flatten()
    # Geodata vector
    user_geodata_vector = user_profile[['user_lat_scaled', 'user_long_scaled']].to_numpy().flatten()
    # Animal vector
    user_animal_vector = user_profile[animals['name']].to_numpy().flatten()

    # generate recommendations
    recommendations = recommend(user_categories_vector, user_geodata_vector, user_animal_vector, w_cat, w_geo, w_animal, n)
    
    dive_sites_indexes = [d['index'] for d in recommendations]

    # return the list of titles and similarities
    recommendations_df = converted_dive_sites.loc[dive_sites_indexes, ['id', 'title', 'lat', 'long', 'occurences', 'categories']]
    recommendations_df[f'Similarity to user {user_id}'] = [d['combined'] for d in recommendations]
    recommendations_df[f'Category Similarity to user {user_id}'] = [d['category'] for d in recommendations]
    recommendations_df[f'Geodata Similarity to user {user_id}'] = [d['geodata'] for d in recommendations] 
    recommendations_df[f'Animal Similarity to user {user_id}'] = [d['animal'] for d in recommendations]

    return recommendations_df

# %% [markdown]
# EXAMPLE RECOMMENDATIONS

# %%
# Find recommendations for user with id 1

ratings, item_profiles = get_item_profile_of_user(target_user_id)
user_profile = generate_user_profile(ratings, item_profiles)
user_profile = normalize_user_profile(user_profile)
user_profile = add_geodata_to_user_profile(user_profile, target_user_id)

user_profile[['user_lat_scaled', 'user_long_scaled']]
# Out:
# User with ID 152e8e72-c295-4a60-9249-63d6aba3be23 has rated 12 dive sites.
#           id  dive_site_id  rating                               user_id
# 0          1          3071     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 1          4          2845     2.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 2          5          3839     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23209  23213          3674     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23210  23214           231     1.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23211  23215          3581     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23212  23216           808     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23213  23217          3333     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23214  23218          1034     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23215  23219          3696     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23216  23220          3101     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23217  23221          2140     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
#    user_lat_scaled  user_long_scaled
# 0         0.201679          0.879698

# %%
example_recommendations = get_recommendations_for_a_user(target_user_id, w_cat=1/3, w_geo=1/3, w_animal=1/3, n=10)

example_recommendations
# Out:
# Generating recommendations for the user with the ID 152e8e72-c295-4a60-9249-63d6aba3be23...
# User with ID 152e8e72-c295-4a60-9249-63d6aba3be23 has rated 12 dive sites.
#           id  dive_site_id  rating                               user_id
# 0          1          3071     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 1          4          2845     2.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 2          5          3839     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23209  23213          3674     4.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23210  23214           231     1.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23211  23215          3581     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23212  23216           808     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23213  23217          3333     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23214  23218          1034     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23215  23219          3696     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23216  23220          3101     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# 23217  23221          2140     5.0  152e8e72-c295-4a60-9249-63d6aba3be23
# Iterate over all dive sites...
#  4394 / 4395
#         id                title       lat       long  \
# 2582  2583  Drum and Drumsticks -35.04489  150.84160
# 4373  4374           Aruh Fanno  -0.29353   73.41174
# 2624  2625        The Long Drop -36.82454  175.82138
# 1094  1095     Menjangan Island  -8.09660  114.51103
# 3710  3711     Basdio Sanctuary   9.74844  124.49909
# 2609  2610       Spectacle Reef -36.82821  175.82365
# 3673  3674        Pontinha deep  16.58343  -22.94435
# 43      44           Henry Head -33.99853  151.23762
# 4100  4101        Latitude Rock -32.20896  152.56634
# 3474  3475      Karacaoren Reef  36.53893   29.05307
#
#                                              occurences  \
# 2582   Moray Eel, Seahorse Family, Seal, Humpback Whale
# 4373                          Grouper, Coral, Moray Eel
# 2624                   Moray Eel, Sea Anemone, Crawfish
# 1094                              Whaleshark, Moray Eel
# 3710                              Nudibranch, Moray Eel
# 2609             Stingray, Moray Eel, Crawfish, Sponges
# 3673                                          Moray Eel
# 43    Cockatoo Cuttlefish, Berycids, Basket Star, Po...
# 4100  Scorpionfish, Sea Turtle, Carpet Sharks, Moray...
# 3474                                          Moray Eel
#
#                            categories  \
# 2582  Reef, Sandy bottom, Wall, Ocean
# 4373                Reef, Wall, Ocean
# 2624      Pinnacle, Reef, Wall, Ocean
# 1094                       Reef, Wall
# 3710         Drift, Reef, Wall, Ocean
# 2609      Pinnacle, Reef, Wall, Ocean
# 3673                Reef, Wall, Ocean
# 43                              Ocean
# 4100                      Reef, Ocean
# 3474                Reef, Wall, Ocean
#
#       Similarity to user 152e8e72-c295-4a60-9249-63d6aba3be23  \
# 2582                                           0.616321
# 4373                                           0.615547
# 2624                                           0.615121
# 1094                                           0.603626
# 3710                                           0.602044
# 2609                                           0.599641
# 3673                                           0.598570
# 43                                             0.598434
# 4100                                           0.592252
# 3474                                           0.589312
#
#       Category Similarity to user 152e8e72-c295-4a60-9249-63d6aba3be23  \
# 2582                                           0.663855
# 4373                                           0.766554
# 2624                                           0.663855
# 1094                                           0.528094
# 3710                                           0.663855
# 2609                                           0.663855
# 3673                                           0.766554
# 43                                             0.580873
# 4100                                           0.625889
# 3474                                           0.766554
#
#       Geodata Similarity to user 152e8e72-c295-4a60-9249-63d6aba3be23  \
# 2582                                           0.885108
# 4373                                           0.733678
# 2624                                           0.835096
# 1094                                           0.858520
# 3710                                           0.718014
# 2609                                           0.835068
# 3673                                           0.429156
# 43                                             0.893246
# 4100                                           0.905917
# 3474                                           0.401382
#
#       Animal Similarity to user 152e8e72-c295-4a60-9249-63d6aba3be23
# 2582                                           0.300000
# 4373                                           0.346410
# 2624                                           0.346410
# 1094                                           0.424264
# 3710                                           0.424264
# 2609                                           0.300000
# 3673                                           0.600000
# 43                                             0.321182
# 4100                                           0.244949
# 3474                                           0.600000

# %%
# Check if the recommendations are correct
# get the item profiles of user with id 1
ratings, item_profiles = get_item_profile_of_user(1)

# generate the user profile
user_profile = generate_user_profile(ratings, item_profiles)
user_profile = normalize_user_profile(user_profile)

user_profile[['lat_scaled', 'long_scaled']] = user.loc[user['id'] == 1, ['user_lat_scaled', 'user_long_scaled']].to_numpy().flatten()

# get values out of the user profile that are not 0
non_zero_features = user_profile.loc[:, (user_profile != 0).any(axis=0)]
non_zero_features
# Out:
# User with ID 1 has rated 13 dive sites.
#       user_id  dive_site_id  rating
# 1228        1          1134       3
# 1229        1          1125       3
# 1230        1          4190       2
# 1231        1            87       3
# 1232        1          1130       3
# 1233        1          1136       2
# 1234        1          3077       2
# 1235        1          4056       3
# 1236        1          3076       4
# 1237        1            39       4
# 1238        1          4186       3
# 1239        1          4191       3
# 1240        1          2968       3
#    Archaeological     Drift      Wall     Beach     Reef     Wreck  \
# 0        0.271312  0.271312  0.406967  0.406967  0.94959  0.678279
#
#    lat_scaled  long_scaled  Moray Eel  Trumpetfish Pipefish  ...  Pufferfish  \
# 0    0.542419     0.688286   0.271312              0.271312  ...    0.406967
#
#    Frogfish     Squid     Drums   Lobster  Cusk Eels  Nudibranch  \
# 0  0.406967  0.406967  0.406967  0.813935   0.678279    0.542623
#
#    Round Stingrays  Seahorse  Yellowtail
# 0         0.406967  0.542623    0.271312
#
# [1 rows x 32 columns]

# %%
# This used to be recommended for user_id=1. It the issue that zero values are taking too much

# get the item profile of the dive site with index 4348
dive_site_4348 = converted_dive_sites.loc[2300]

# convert the Series to a DataFrame
dive_site_4348 = dive_site_4348.to_frame().T

# filter out columns with all zero values
dive_site_4348 = dive_site_4348.loc[:, (dive_site_4348 != 0).any(axis=0)]

dive_site_4348
# Out:
#         id          title      lat      long  \
# 2300  2301  Koh Ha Lagoon  7.42942  98.89539
#
#                                             description  \
# 2300  A beautiful site - perfect for both diving and...
#
#                                               image_url  \
# 2300  https://d2p1cf6997m1ir.cloudfront.net/media/th...
#
#                                                     url max_depth    region  \
# 2300  https://www.padi.com/dive-site/thailand/koh-ha...      None  Thailand
#
#      cluster  ... Squid Pistol Shrimp Lobster Pipefish Whaleshark  \
# 2300       7  ...     1             1       1        1          1
#
#      Crown-Of-Thorns Starfish Elapids Seahorse  \
# 2300                        1       1        1
#
#                                              occurences categories
# 2300  Squid, Frogfish, Crown-Of-Thorns Starfish, Gho...       Reef
#
# [1 rows x 48 columns]
